# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataSet=pd.read_csv('adaboostAnalysis.csv')
dataSet.head()
# Out:
#                                        dataSet  accuracy
# 0                                     kyphosis     80.80
# 1                                breast_cancer     96.27
# 2                                         iris    100.00
# 3  biomechanical-feature-of-orthopedic-patient     38.50
# 4                    carvan-insurance-chalange     57.80

# %%
dataSet['dataSet']
# Out:
# 0                                        kyphosis
# 1                                   breast_cancer
# 2                                            iris
# 3     biomechanical-feature-of-orthopedic-patient
# 4                       carvan-insurance-chalange
# 5                             faulty-steel-plates
# 6                            glass-classification
# 7                            indian-liver-patient
# 8                         mushroom-classification
# 9                            pima-indian-diabetes
# 10                                    horse-colic
# 11                                        pokeman
# 12                                uci-credit-card
# 13                      zoo-animal-classification
# 14                                       red-wine
# 15                            wall-fllowing-robot
# 16                                 bank-marketing
# 17                    student-alcohol-consumption
# 18                          gender-classification
# ...

# %%
sns.barplot(x='dataSet',y='accuracy',data=dataSet)
sns.set(rc={'figure.figsize':(25,10)})

# %%
fig=sns.kdeplot(dataSet['accuracy'],shade=True)

# %%
sns.barplot(y='dataSet',x='accuracy',data=dataSet)
sns.set(rc={'figure.figsize':(20,12)})

# %%
fig.figure.savefig('file.png')
