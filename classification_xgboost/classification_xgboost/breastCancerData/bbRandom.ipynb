# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,recall_score,confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataSet = pd.read_csv('breastCancerData.csv',index_col=32)
dataSet.head()
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# NaN    842302         M        17.99         10.38          122.80     1001.0
# NaN    842517         M        20.57         17.77          132.90     1326.0
# NaN  84300903         M        19.69         21.25          130.00     1203.0
# NaN  84348301         M        11.42         20.38           77.58      386.1
# NaN  84358402         M        20.29         14.34          135.10     1297.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# NaN          0.11840           0.27760          0.3001              0.14710
# NaN          0.08474           0.07864          0.0869              0.07017
# NaN          0.10960           0.15990          0.1974              0.12790
# NaN          0.14250           0.28390          0.2414              0.10520
# NaN          0.10030           0.13280          0.1980              0.10430
#
#               ...             radius_worst  texture_worst  perimeter_worst  \
# NaN           ...                    25.38          17.33           184.60
# NaN           ...                    24.99          23.41           158.80
# NaN           ...                    23.57          25.53           152.50
# NaN           ...                    14.91          26.50            98.87
# NaN           ...                    22.54          16.67           152.20
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# NaN      2019.0            0.1622             0.6656           0.7119
# NaN      1956.0            0.1238             0.1866           0.2416
# NaN      1709.0            0.1444             0.4245           0.4504
# NaN       567.7            0.2098             0.8663           0.6869
# NaN      1575.0            0.1374             0.2050           0.4000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# NaN                0.2654          0.4601                  0.11890
# NaN                0.1860          0.2750                  0.08902
# NaN                0.2430          0.3613                  0.08758
# NaN                0.2575          0.6638                  0.17300
# NaN                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
#catagorical feature for encoding purpose
cat_feats = ['diagnosis']

# %%
#to create a fixed larger dataframe that has new feature columns with dummy variables. Set this dataframe as final_data.
final_data = pd.get_dummies(dataSet,columns=cat_feats,drop_first=True)
final_data.head()
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# NaN    842302        17.99         10.38          122.80     1001.0
# NaN    842517        20.57         17.77          132.90     1326.0
# NaN  84300903        19.69         21.25          130.00     1203.0
# NaN  84348301        11.42         20.38           77.58      386.1
# NaN  84358402        20.29         14.34          135.10     1297.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# NaN          0.11840           0.27760          0.3001              0.14710
# NaN          0.08474           0.07864          0.0869              0.07017
# NaN          0.10960           0.15990          0.1974              0.12790
# NaN          0.14250           0.28390          0.2414              0.10520
# NaN          0.10030           0.13280          0.1980              0.10430
#
#      symmetry_mean     ...       texture_worst  perimeter_worst  area_worst  \
# NaN         0.2419     ...               17.33           184.60      2019.0
# NaN         0.1812     ...               23.41           158.80      1956.0
# NaN         0.2069     ...               25.53           152.50      1709.0
# NaN         0.2597     ...               26.50            98.87       567.7
# NaN         0.1809     ...               16.67           152.20      1575.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# NaN            0.1622             0.6656           0.7119
# NaN            0.1238             0.1866           0.2416
# NaN            0.1444             0.4245           0.4504
# NaN            0.2098             0.8663           0.6869
# NaN            0.1374             0.2050           0.4000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# NaN                0.2654          0.4601                  0.11890
# NaN                0.1860          0.2750                  0.08902
# NaN                0.2430          0.3613                  0.08758
# NaN                0.2575          0.6638                  0.17300
# NaN                0.1625          0.2364                  0.07678
#
#      diagnosis_M
# NaN            1
# NaN            1
# NaN            1
# NaN            1
# NaN            1
#
# [5 rows x 32 columns]

# %%
    #train and test data set spilitting
    X = final_data.drop('diagnosis_M',axis=1)
    y = final_data['diagnosis_M']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
accuracies.mean()
#accuracies.std()
# Out:
# 0.96273452157598505

# %%
# Making the Confusion Matrix
#a=confusion_matrix(y_test, y_pred)
# Out:
# array([[101,   4],
#        [  2,  64]])

# %%
b=(a[0][0]+a[1][1])/(a[0][0]+a[0][1]+a[1][0]+a[1][1])
b
# Out:
# 0.96491228070175439
